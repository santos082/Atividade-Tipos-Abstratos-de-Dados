# %% [markdown]
# # Exercício 1
# Implementar uma pilha simples utilizando uma lista.
# 1. Crie uma pilha vazia (utilizando uma lista).
# 2. Empilhe (adicione) os números 5, 10 e 15 na pilha.
# 3. Mostre o topo da pilha (último elemento).
# 4. Desempilhe (remova) o topo da pilha e mostre o novo topo.
# 5. Verifique se a pilha está vazia e imprima o resultado.

# %%
# 1. 
pilha = []

# 2. 
pilha.append(5)
pilha.append(10)
pilha.append(15)

# 3. 
print("Topo da pilha:", pilha[-1])

# 4. 
pilha.pop()
print("Novo topo:", pilha[-1])

# 5.
if len(pilha) == 0:
    print("A pilha está vazia")
else:
    print("A pilha NÃO está vazia")
# Out:
# Running cells with 'Python 3.12.10' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/90041124804/AppData/Local/Microsoft/WindowsApps/python3.12.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # Exercício 2
# Criar uma pilha e manipular seus elementos.
# 1. Crie uma pilha utilizando uma lista.
# 2. Empilhe 3 números inteiros de sua escolha.
# 3. Mostre o topo da pilha.
# 4. Desempilhe o topo e mostre o novo topo.
# 5. Tente desempilhar todos os elementos e mostrar se a pilha ficou vazia.

# %%
# 1. 
pilha = []

# 2. 
pilha.append(5)
pilha.append(10)
pilha.append(15)

# 3. 
print("Topo da pilha:", pilha[-1])

# 4.  da pra usar o .clear()
pilha.pop()
print("Novo topo:", pilha[-1])

#5.
pilha.pop()
pilha.pop()
print("Nova pilha:", pilha)

#  outra opcao de fazer o passo 5
'''
if len(pilha) == 0:
    print("A pilha está vazia")
else:
    print("A pilha NÃO está vazia")

'''

# %% [markdown]
# # Exercício 3
# Você foi contratado para desenvolver uma funcionalidade de “Desfazer/Refazer"
# para um editor de texto simples. O editor permite que o usuário escreva palavras
# em um documento, e, caso cometa um erro, pode desfazer a última ação ou
# refazê-la caso mude de ideia.

# %%
class Stack:
    def __init__(self):  # <-- corrigido aqui
        self.items = []

    def push(self, item):
        self.items.append(item)

    def pop(self):
        if self.items:
            return self.items.pop()
        return None

    def show(self):
        for palavra in self.items:
            print(palavra, end=" ")
        print()  # quebra de linha


# uso
editor = Stack()

editor.push("Olá")
editor.push("mundo")
editor.push("Python")

print("Texto:")
editor.show()

# desfazer
editor.pop()

print("Depois de desfazer:")
editor.show()

# %% [markdown]
# # Exercício 4
#
# Criar uma implementação simples de uma fila (Queue) usando listas.
# 1. Crie uma fila vazia.
# 2. Enfileire 3 números inteiros na fila.
# 3. Mostre o primeiro elemento da fila.
#
# 4. Desenfileire o primeiro elemento e mostre o novo primeiro elemento.
# 5. Verifique se a fila está vazia após as remoções.

# %%
fila = []

# 1. 

# 2. enfileirar
fila.append(10)
fila.append(20)
fila.append(30)

# 3. 
print("Primeiro:", fila[0])

# 4. remover 
fila.pop(0)
print("Novo primeiro:", fila[0])

# 5. verificar
print("Fila vazia?", len(fila) == 0)
# Out:
# Running cells with 'Python 3.12.10' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/90041124804/AppData/Local/Microsoft/WindowsApps/python3.12.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # Exercício 5
# Um consultório odontológico precisa gerenciar a ordem de atendimento dos
# pacientes. Para isso, foi decidido implementar uma fila onde os pacientes são
# chamados na ordem em que chegaram (FIFO – First In, First Out).

# %%
fila = []

# pacientes chegando
fila.append("João")
fila.append("Maria")
fila.append("Carlos")

# atendimento
while fila:
    paciente = fila.pop(0)
    print("Atendendo:", paciente)

# %% [markdown]
# # Exercício 6
# Uma impressora trabalha com um sistema de fila para processar documentos
# enviados para impressão. Cada documento enviado entra no final da fila e será
# impresso na ordem em que chegou.
# • Crie uma fila vazia para representar a fila de impressão.
# • Enfileire três documentos (nomes de arquivos) na fila.
# • Mostre qual documento será impresso primeiro.
# • Desenfileire o primeiro documento e mostre o próximo da fila.
# • Verifique se ainda há documentos na fila após as remoções.

# %%
fila = []

# enfileirar documentos dentro da fila
fila.append("doc1.pdf")
fila.append("doc2.pdf")
fila.append("doc3.pdf")

# primeiro documento
print("Primeiro:", fila[0])

# remover o ultimo e mostrar o próximo
fila.pop(0)
print("Próximo:", fila[0])

# verificar se ainda tem
print("Ainda há documentos?", len(fila) > 0)

# %% [markdown]
# # Exercício 7
# Uma central de atendimento telefônico gerencia chamadas em espera usando
# uma pilha. Isso significa que a última chamada recebida será a primeira a ser
# atendida.
# • Crie uma pilha vazia para armazenar as chamadas em espera.
# • Empilhe três chamadas com identificadores numéricos.
# • Mostre qual chamada será atendida primeiro.
# • Atenda a última chamada recebida e mostre a nova chamada no topo da
# pilha.
# • Verifique se ainda há chamadas na pilha após os atendimentos.

# %%
pilha = []

# empilhar chamadas
pilha.append(1)
pilha.append(2)
pilha.append(3)

# oq esta no topo
print("Próxima chamada:", pilha[-1])

# atender (pop)
pilha.pop()
print("Novo topo:", pilha[-1])

# verificar se ainda tem algo dentro da pilha
print("Ainda há chamadas?", len(pilha) > 0)

# %% [markdown]
# # Exercício 8 - Extra
# Um navegador de internet usa uma pilha para armazenar o histórico de
# navegação. Cada vez que o usuário acessa uma nova página, ela é adicionada
# ao histórico. O usuário pode voltar para a página anterior ou avançar
# novamente.
# • Crie uma pilha para armazenar as páginas visitadas.
# • Empilhe três páginas acessadas pelo usuário.
# • Mostre a última página visitada.
# • O usuário clica no botão "Voltar", então desempilhe a última página
# visitada e mostre a nova página no topo.
# • O usuário decide avançar novamente. Como o histórico de páginas
# acessadas foi modificado, implemente um sistema para refazer a
# navegação caso necessário.

# %%
class Navegador:
    def __init__(self):  # corrigido aqui
        self.voltar = []
        self.avancar = []

    def acessar(self, pagina):
        self.voltar.append(pagina)
        self.avancar.clear()

    def voltar_pagina(self):
        if len(self.voltar) > 1:
            pagina = self.voltar.pop()
            self.avancar.append(pagina)

    def avancar_pagina(self):
        if self.avancar:
            pagina = self.avancar.pop()
            self.voltar.append(pagina)

    def atual(self):
        return self.voltar[-1]


# Teste
nav = Navegador()

nav.acessar("google.com")
nav.acessar("youtube.com")
nav.acessar("github.com")

print("Atual:", nav.atual())

nav.voltar_pagina()
print("Depois de voltar:", nav.atual())

nav.avancar_pagina()
print("Depois de avançar:", nav.atual())
# Out:
# Running cells with 'Python 3.12.10' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/90041124804/AppData/Local/Microsoft/WindowsApps/python3.12.exe -m pip install ipykernel -U --user --force-reinstall'
